# %%
# !pwd
# Out:
# /afs/cern.ch/work/a/apoyet/lhcmask/tests/run3_wires

# %%
# !which python
# Out:
# /cvmfs/sft.cern.ch/lcg/views/LCG_96python3/x86_64-centos7-gcc8-opt/bin/python

# %%
from cpymad.madx import Madx 
import pandas as pd

# %%
madx = Madx()
# Out:
#   ++++++++++++++++++++++++++++++++++++++++++++
#   +     MAD-X 5.05.01  (64 bit, Linux)       +
#   + Support: mad@cern.ch, http://cern.ch/mad +
#   + Release   date: 2019.06.07               +
#   + Execution date: 2020.02.27 16:38:21      +
#   ++++++++++++++++++++++++++++++++++++++++++++

# %%
madx.input("call, file=run3_collisions.mask;");
# Out:
# !*************************!
#
# !   Prepare environment   !
#
# !*************************!
#
#
#
# option, warn, info;
#
#
#
# system, "rm -rf temp";
#
# system, "mkdir temp";
#
#
#
# system, "ln -fns /afs/cern.ch/eng/lhc/optics/V6.503 db5";
#
# system, "ln -fns /afs/cern.ch/eng/lhc/optics/HLLHCV1.4 slhc";
#
#
#
# ! TODO: To be put in the optics repository
#
# system, "ln -fns /afs/cern.ch/work/f/fvanderv/projects/HL14errors/ fre";
#
#
#
# ! Beam-beam macros folder
#
# system, "ln -fns /afs/cern.ch/eng/lhc/optics/simulation_tools/beambeam_macros beambeam_macros";
#
#
#
# ! Mask code folder
#
# system, "ln -fns ../../ mask_code";
#
#
#
#
#
# !*************************!
#
# !  General configuration  !
#
# !*************************!
#
#
#
# ! Choose build sequence script
#
# system, "ln -fns build_run3_seq.madx buildsequence.madx";
#
#
#
# ! Define the optics
#
# !system, "ln -fns /afs/cern.ch/eng/lhc/optics/runIII/RunIII_dev/2022_V1/PROTON/opticsfile.30 myoptics.madx";
#
# ...

# %%
madx.input('''
use, sequence=lhcb1;
twiss;
''')
# Out:
# enter Twiss module
#
# iteration:   1 error:   3.507877E-06 deltap:   0.000000E+00
# orbit:  -4.154559E-06  4.933693E-08 -3.345430E-06 -5.450883E-08  0.000000E+00  0.000000E+00
#
# iteration:   2 error:   1.353290E-06 deltap:   0.000000E+00
# orbit:  -4.353415E-06  6.179690E-08 -3.322616E-06 -5.182580E-08  0.000000E+00  0.000000E+00
#
# iteration:   3 error:   7.866247E-08 deltap:   0.000000E+00
# orbit:  -4.538592E-06  6.333421E-08 -3.368554E-06 -5.259950E-08  0.000000E+00  0.000000E+00
#
# ++++++ table: summ
#
# length orbit5 alfa gammatr
# 26658.883199996 -0 0.000348161798503663 53.5931694330521
#
# q1 dq1 betxmax dxmax
# 62.3036247625668 1.41884313700194 9017.90785835604 3.34496172141119
#
# dxrms xcomax xcorms q2
# 1.43695702340894 0.00972343048748374 0.00158921364342228 60.3212757483167
#
# dq2 betymax dymax dyrms
# 0.941928203968077 9113.32739036797 2.73959060936377 0.478428991049782
#
# ycomax ycorms deltap synch_1
# 0.00826952555986786 0.00144896422143096 0 0
#
# ...

# %%
my_twiss = madx.table.twiss.dframe()

# %%
my_twiss[my_twiss['name'].str.contains('bbcw_')]
# Out:
#                             name   keyword             s         betx  \
# bbcw_opp_l5.b1  bbcw_opp_l5.b1:1  beambeam   6516.623433  2779.999009
# bbcw_l5.b1          bbcw_l5.b1:1  beambeam   6516.623433  2779.999069
# bbcw_opp_l1.b1  bbcw_opp_l1.b1:1  beambeam  19848.217400  2180.759420
# bbcw_l1.b1          bbcw_l1.b1:1  beambeam  19848.217400  2180.759881
#
#                     alfx        mux         bety       alfy        muy  \
# bbcw_opp_l5.b1 -5.130525  14.694815  1159.226646 -20.287178  14.024430
# bbcw_l5.b1     -5.397245  14.694815  1159.226671 -20.175959  14.024430
# bbcw_opp_l1.b1 -4.012648  46.057330   971.609708 -16.447108  44.742511
# bbcw_l1.b1     -3.804173  46.057330   971.609913 -16.539995  44.742511
#
#                        x  ...         sig54         sig55  sig56  sig61  \
# bbcw_opp_l5.b1 -0.002057  ... -1.678413e-14  1.274426e-11    0.0    0.0
# bbcw_l5.b1     -0.002057  ... -1.575803e-14  1.274426e-11    0.0    0.0
# ...

# %%
madx.input('''

''')
